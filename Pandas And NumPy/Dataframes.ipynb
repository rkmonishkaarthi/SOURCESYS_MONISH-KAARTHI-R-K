# %%
import pandas as pd

list = pd.Series([70,80,90])
print(list)

df1 = pd.DataFrame({"Name": ["A","B","C"],"Marks": [95,92,96],"rank": [2,3,1]})

print(df1)

df2 = pd.DataFrame({"A": [85,70,67,95],"B": [90,82,77,93]})

print(df2)

df3 = pd.DataFrame([[5,6],[7,8]], columns=["A","B"])
print(df3)

import numpy as np
df4 = pd.DataFrame(np.random.rand(3,2), columns=["A","B"])
print(df4)
# Out:
# 0    70
# 1    80
# 2    90
# dtype: int64
#   Name  Marks  rank
# 0    A     95     2
# 1    B     92     3
# 2    C     96     1
#     A   B
# 0  85  90
# 1  70  82
# 2  67  77
# 3  95  93
#    A  B
# 0  5  6
# 1  7  8
#           A         B
# 0  0.247183  0.338666
# 1  0.621726  0.720725
# 2  0.248555  0.891275
